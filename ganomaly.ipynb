# %% [markdown]
# <a href="https://colab.research.google.com/github/esma-nur/Anomaly-Detection-Anomalib-Library/blob/main/ganomaly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
DATA_DIR = '/content/drive/MyDrive/mv-tec-wood'

# %%
# !pip install anomalib==0.3.6
# Out:
# Requirement already satisfied: anomalib==0.3.6 in /usr/local/lib/python3.10/dist-packages (0.3.6)
# Requirement already satisfied: albumentations>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (1.3.1)
# Requirement already satisfied: einops>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (0.8.0)
# Requirement already satisfied: gradio>=2.9.4 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (4.28.3)
# Requirement already satisfied: imgaug==0.4.0 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (0.4.0)
# Requirement already satisfied: jsonargparse[signatures]>=4.3 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (4.28.0)
# Requirement already satisfied: kornia>=0.6.6 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (0.6.9)
# Requirement already satisfied: matplotlib>=3.4.3 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (3.7.1)
# Requirement already satisfied: omegaconf>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (2.3.0)
# Requirement already satisfied: opencv-python>=4.5.3.56 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (4.8.0.76)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (2.0.3)
# Requirement already satisfied: pytorch-lightning<1.7.0,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (1.6.5)
# Requirement already satisfied: timm==0.5.4 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (0.5.4)
# Requirement already satisfied: torchmetrics<=0.9.3,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (0.9.3)
# Requirement already satisfied: torchvision<=0.12.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (0.12.0)
# Requirement already satisfied: torchtext<=0.12.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (0.12.0)
# Requirement already satisfied: wandb==0.12.17 in /usr/local/lib/python3.10/dist-packages (from anomalib==0.3.6) (0.12.17)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->anomalib==0.3.6) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->anomalib==0.3.6) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->anomalib==0.3.6) (1.11.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->anomalib==0.3.6) (9.4.0)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->anomalib==0.3.6) (0.19.3)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->anomalib==0.3.6) (2.31.6)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->anomalib==0.3.6) (2.0.4)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from timm==0.5.4->anomalib==0.3.6) (1.11.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (8.1.7)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (3.1.43)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (2.8.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (2.31.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (2.3)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (1.0.13)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (2.0.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (0.4.0)
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (3.20.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (6.0.1)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (0.1.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.17->anomalib==0.3.6) (67.7.2)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations>=1.1.0->anomalib==0.3.6) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations>=1.1.0->anomalib==0.3.6) (4.9.0.80)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (4.2.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (0.110.2)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (0.3.2)
# Requirement already satisfied: gradio-client==0.16.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (0.16.0)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (0.20.3)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (3.10.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (24.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (2.7.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (0.0.9)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (0.4.2)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (4.11.0)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (2.0.7)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=2.9.4->anomalib==0.3.6) (0.29.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.16.0->gradio>=2.9.4->anomalib==0.3.6) (2023.6.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.16.0->gradio>=2.9.4->anomalib==0.3.6) (11.0.3)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.10/dist-packages (from jsonargparse[signatures]>=4.3->anomalib==0.3.6) (0.16)
# Requirement already satisfied: typeshed-client>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from jsonargparse[signatures]>=4.3->anomalib==0.3.6) (2.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.3->anomalib==0.3.6) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.3->anomalib==0.3.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.3->anomalib==0.3.6) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.3->anomalib==0.3.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.3->anomalib==0.3.6) (3.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.1.1->anomalib==0.3.6) (4.9.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->anomalib==0.3.6) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->anomalib==0.3.6) (2024.1)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (4.66.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (2.15.2)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (0.3.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio>=2.9.4->anomalib==0.3.6) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio>=2.9.4->anomalib==0.3.6) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio>=2.9.4->anomalib==0.3.6) (0.12.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec->gradio-client==0.16.0->gradio>=2.9.4->anomalib==0.3.6) (3.9.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython>=1.0.0->wandb==0.12.17->anomalib==0.3.6) (4.0.11)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio>=2.9.4->anomalib==0.3.6) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio>=2.9.4->anomalib==0.3.6) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio>=2.9.4->anomalib==0.3.6) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio>=2.9.4->anomalib==0.3.6) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio>=2.9.4->anomalib==0.3.6) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio>=2.9.4->anomalib==0.3.6) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio>=2.9.4->anomalib==0.3.6) (3.13.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio>=2.9.4->anomalib==0.3.6) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio>=2.9.4->anomalib==0.3.6) (2.18.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations>=1.1.0->anomalib==0.3.6) (1.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.12.17->anomalib==0.3.6) (3.3.2)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug==0.4.0->anomalib==0.3.6) (3.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug==0.4.0->anomalib==0.3.6) (2024.4.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug==0.4.0->anomalib==0.3.6) (1.6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (1.62.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (3.0.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio>=2.9.4->anomalib==0.3.6) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio>=2.9.4->anomalib==0.3.6) (13.7.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio>=2.9.4->anomalib==0.3.6) (0.37.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.16.0->gradio>=2.9.4->anomalib==0.3.6) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.16.0->gradio>=2.9.4->anomalib==0.3.6) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.16.0->gradio>=2.9.4->anomalib==0.3.6) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.16.0->gradio>=2.9.4->anomalib==0.3.6) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.16.0->gradio>=2.9.4->anomalib==0.3.6) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.16.0->gradio>=2.9.4->anomalib==0.3.6) (4.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb==0.12.17->anomalib==0.3.6) (5.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.2.0->pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (1.3.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio>=2.9.4->anomalib==0.3.6) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio>=2.9.4->anomalib==0.3.6) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio>=2.9.4->anomalib==0.3.6) (0.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=2.9.4->anomalib==0.3.6) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=2.9.4->anomalib==0.3.6) (2.16.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations>=1.1.0->anomalib==0.3.6) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations>=1.1.0->anomalib==0.3.6) (3.4.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.24.1->gradio>=2.9.4->anomalib==0.3.6) (1.2.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio>=2.9.4->anomalib==0.3.6) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.2.0->pytorch-lightning<1.7.0,>=1.6.0->anomalib==0.3.6) (3.2.2)

# %%
# !pip install kornia==0.6.9
# Out:
# Requirement already satisfied: kornia==0.6.9 in /usr/local/lib/python3.10/dist-packages (0.6.9)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kornia==0.6.9) (24.0)
# Requirement already satisfied: torch>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from kornia==0.6.9) (1.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia==0.6.9) (4.11.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import os, pprint, yaml, warnings, math, glob, cv2, random, logging

def warn(*args, **kwargs):
    pass
warnings.warn = warn
warnings.filterwarnings('ignore')
logger = logging.getLogger("anomalib")

import anomalib

# %%
print(anomalib.__version__)
# Out:
# 0.3.6

# %%
from pytorch_lightning import Trainer, seed_everything

# %%
import anomalib
from pytorch_lightning import Trainer, seed_everything
from anomalib.models import get_model
from anomalib.data import get_datamodule
from anomalib.utils.loggers import configure_logger, get_experiment_logger
from anomalib.utils.callbacks import LoadModelCallback, get_callbacks
from anomalib.config import get_configurable_parameters

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.backends.cudnn.version())
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())
print(torch.cuda.device(0))
print(torch.cuda.get_device_name(0))
# Out:
# 1.11.0+cu102
# 10.2
# 7605
# True
# 1
# 0
# <torch.cuda.device object at 0x7ed51095f430>
# Tesla T4

# %% [markdown]
# Model Config Path
#
# Currently, there are 10 anomaly detection models available in anomalib library. Namely,
#
# Patchcore
# Padim
# DFKDE
# DFM
# CFlow
# Ganomaly
# STFPM
# FastFlow
# DREAM
# Reverse Distillation

# %%
CONFIG_PATHS = '/usr/local/lib/python3.10/dist-packages/anomalib/models'
MODEL_CONFIG_PAIRS = {
    'patchcore': f'{CONFIG_PATHS}/patchcore/config.yaml',
    'padim':     f'{CONFIG_PATHS}/padim/config.yaml',
    'cflow':     f'{CONFIG_PATHS}/cflow/config.yaml',
    'dfkde':     f'{CONFIG_PATHS}/dfkde/config.yaml',
    'dfm':       f'{CONFIG_PATHS}/dfm/config.yaml',
    'ganomaly':  f'{CONFIG_PATHS}/ganomaly/config.yaml',
    'stfpm':     f'{CONFIG_PATHS}/stfpm/config.yaml',
    'fastflow':  f'{CONFIG_PATHS}/fastflow/config.yaml',
    'draem':     f'{CONFIG_PATHS}/draem/config.yaml',
    'reverse_distillation': f'{CONFIG_PATHS}/reverse_distillation/config.yaml',
}

# %%
MODEL = 'ganomaly'
print(open(os.path.join(MODEL_CONFIG_PAIRS[MODEL]), 'r').read())
# Out:
# dataset:
#   name: mvtec #options: [mvtec, btech, folder]
#   format: mvtec
#   path: ./datasets/MVTec
#   category: bottle
#   task: classification
#   image_size: 256
#   train_batch_size: 32
#   test_batch_size: 32
#   inference_batch_size: 32
#   num_workers: 8
#   transform_config:
#     train: null
#     val: null
#   create_validation_set: false
#   tiling:
#     apply: true
#     tile_size: 64
#     stride: null
#     remove_border_count: 0
#     use_random_tiling: False
#     random_tile_count: 16
#
# model:
#   name: ganomaly
#   latent_vec_size: 100
#   n_features: 64
#   extra_layers: 0
#   add_final_conv: true
#   early_stopping:
#     patience: 3
#     metric: image_AUROC
#     mode: max
#   lr: 0.0002
#   beta1: 0.5
#   beta2: 0.999
#   wadv: 1
#   wcon: 50
#   wenc: 1
#   normalization_method: none
#
# metrics:
#   image:
#     - F1Score
#     - AUROC
#   threshold:
#     image_default: 0
#     adaptive: true
#
# visualization:
#   show_images: False # show images on the screen
#   save_images: True # save images to the file system
#   log_images: True # log images to the available loggers (if any)
#   image_save_path: null # path to which images will be saved
#   mode: full # options: ["full", "simple"]
#
# project:
#   seed: 42
#   path: ./results
#
# logging:
#   logger: [] # options: [tensorboard, wandb, csv] or combinations.
#   log_graph: false # Logs the model graph to respective logger.
#
# optimization:
#   export_mode: ""
#
# # PL Trainer Args. Don't add extra parameter here.
# trainer:
#   accelerator: auto # <"cpu", "gpu", "tpu", "ipu", "hpu", "auto">
#   accumulate_grad_batches: 1
#   amp_backend: native
#   auto_lr_find: false
#   auto_scale_batch_size: false
#   auto_select_gpus: false
#   benchmark: false
#   check_val_every_n_epoch: 2
#   default_root_dir: null
#   detect_anomaly: false
#   deterministic: false
#   devices: 1
#   enable_checkpointing: true
#   enable_model_summary: true
#   enable_progress_bar: true
#   fast_dev_run: false
#   gpus: null # Set automatically
#   gradient_clip_val: 0
#   ipus: null
#   limit_predict_batches: 1.0
#   limit_test_batches: 1.0
#   limit_train_batches: 1.0
#   limit_val_batches: 1.0
#   log_every_n_steps: 50
#   log_gpu_memory: null
#   max_epochs: 100
#   max_steps: null
#   min_epochs: null
#   min_steps: null
#   move_metrics_to_cpu: false
#   multiple_trainloader_mode: max_size_cycle
#   num_nodes: 1
#   num_processes: null
#   num_sanity_val_steps: 0
#   overfit_batches: 0.0
#   plugins: null
#   precision: 32
#   profiler: null
#   reload_dataloaders_every_n_epochs: 0
#   replace_sampler_ddp: true
#   strategy: null
#   sync_batchnorm: false
#   tpu_cores: null
#   track_grad_norm: -1
#   val_check_interval: 1.0

# %%
DATA_DIR = '/usr/local/lib/python3.10/dist-packages/anomalib/'

# %%
new_update = {
    "path": '/content/drive/MyDrive/mv-tec-wood',
    'category': 'wood',
    'image_size': 256,
    'train_batch_size':48,
    'seed': 101
}

# %%
# update yaml key's value
def update_yaml(old_yaml, new_yaml, new_update):
    # load yaml
    with open(old_yaml) as f:
        old = yaml.safe_load(f)

    temp = []
    def set_state(old, key, value):
        if isinstance(old, dict):
            for k, v in old.items():
                if k == 'project':
                    temp.append(k)
                if k == key:
                    if temp and k == 'path':
                        # right now, we don't wanna change `project.path`
                        continue
                    old[k] = value
                elif isinstance(v, dict):
                    set_state(v, key, value)

    # iterate over the new update key-value pari
    for key, value in new_update.items():
        set_state(old, key, value)

    # save the updated / modified yaml file
    with open(new_yaml, 'w') as f:
        yaml.safe_dump(old, f, default_flow_style=False)

# %%
# let's set a new path location of new config file
new_yaml_path = CONFIG_PATHS + '/' + list(MODEL_CONFIG_PAIRS.keys())[0] + '_new.yaml'

# run the update yaml method to update desired key's values
update_yaml(MODEL_CONFIG_PAIRS[MODEL], new_yaml_path, new_update)

# %%
with open(new_yaml_path) as f:
    updated_config = yaml.safe_load(f)
pprint.pprint(updated_config) # check if it's updated
# Out:
# {'dataset': {'category': 'wood',
#              'create_validation_set': False,
#              'format': 'mvtec',
#              'image_size': 256,
#              'inference_batch_size': 32,
#              'name': 'mvtec',
#              'num_workers': 8,
#              'path': '/content/drive/MyDrive/mv-tec-wood',
#              'task': 'classification',
#              'test_batch_size': 32,
#              'tiling': {'apply': True,
#                         'random_tile_count': 16,
#                         'remove_border_count': 0,
#                         'stride': None,
#                         'tile_size': 64,
#                         'use_random_tiling': False},
#              'train_batch_size': 48,
#              'transform_config': {'train': None, 'val': None}},
#  'logging': {'log_graph': False, 'logger': []},
#  'metrics': {'image': ['F1Score', 'AUROC'],
#              'threshold': {'adaptive': True, 'image_default': 0}},
#  'model': {'add_final_conv': True,
#            'beta1': 0.5,
#            'beta2': 0.999,
#            'early_stopping': {'metric': 'image_AUROC',
#                               'mode': 'max',
#                               'patience': 3},
#            'extra_layers': 0,
#            'latent_vec_size': 100,
#            'lr': 0.0002,
#            'n_features': 64,
#            'name': 'ganomaly',
#            'normalization_method': 'none',
#            'wadv': 1,
#            'wcon': 50,
#            'wenc': 1},
#  'optimization': {'export_mode': ''},
#  'project': {'path': './results', 'seed': 101},
#  'trainer': {'accelerator': 'auto',
#              'accumulate_grad_batches': 1,
#              'amp_backend': 'native',
#              'auto_lr_find': False,
#              'auto_scale_batch_size': False,
#              'auto_select_gpus': False,
#              'benchmark': False,
#              'check_val_every_n_epoch': 2,
#              'default_root_dir': None,
#              'detect_anomaly': False,
#              'deterministic': False,
#              'devices': 1,
#              'enable_checkpointing': True,
#              'enable_model_summary': True,
#              'enable_progress_bar': True,
#              'fast_dev_run': False,
#              'gpus': None,
#              'gradient_clip_val': 0,
#              'ipus': None,
#              'limit_predict_batches': 1.0,
#              'limit_test_batches': 1.0,
#              'limit_train_batches': 1.0,
#              'limit_val_batches': 1.0,
#              'log_every_n_steps': 50,
#              'log_gpu_memory': None,
#              'max_epochs': 100,
#              'max_steps': None,
#              'min_epochs': None,
#              'min_steps': None,
#              'move_metrics_to_cpu': False,
#              'multiple_trainloader_mode': 'max_size_cycle',
#              'num_nodes': 1,
#              'num_processes': None,
#              'num_sanity_val_steps': 0,
#              'overfit_batches': 0.0,
#              'plugins': None,
#              'precision': 32,
#              'profiler': None,
#              'reload_dataloaders_every_n_epochs': 0,
#              'replace_sampler_ddp': True,
#              'strategy': None,
#              'sync_batchnorm': False,
#              'tpu_cores': None,
#              'track_grad_norm': -1,
#              'val_check_interval': 1.0},
#  'visualization': {'image_save_path': None,
#                    'log_images': True,
#                    'mode': 'full',
#                    'save_images': True,
#                    'show_images': False}}

# %%
if updated_config['project']['seed'] != 0:
    print(updated_config['project']['seed'])
    seed_everything(updated_config['project']['seed'])
# Out:
# INFO:pytorch_lightning.utilities.seed:Global seed set to 101
# 101

# %%
# It will return the configurable parameters in DictConfig object.
config = get_configurable_parameters(
    model_name=updated_config['model']['name'],
    config_path=new_yaml_path
)

# %%
# pass the config file to model, logger, callbacks and datamodule
model      = get_model(config)
experiment_logger = get_experiment_logger(config)
callbacks  = get_callbacks(config)
datamodule = get_datamodule(config)

# %%
# start training
trainer = Trainer(**config.trainer, logger=experiment_logger, callbacks=callbacks)
trainer.fit(model=model, datamodule=datamodule)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True, used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(limit_predict_batches=1.0)` was configured so 100% of the batches will be used..
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# INFO:pytorch_lightning.accelerators.gpu:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name               | Type                     | Params
# ----------------------------------------------------------------
# 0 | image_threshold    | AdaptiveThreshold        | 0
# 1 | pixel_threshold    | AdaptiveThreshold        | 0
# 2 | model              | GanomalyModel            | 188 M
# 3 | generator_loss     | GeneratorLoss            | 0
# 4 | discriminator_loss | DiscriminatorLoss        | 0
# 5 | image_metrics      | AnomalibMetricCollection | 0
# 6 | pixel_metrics      | AnomalibMetricCollection | 0
# ----------------------------------------------------------------
# 188 M     Trainable params
# 0         Non-trainable params
# 188 M     Total params
# 754.758   Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %%
# load best model from checkpoint before evaluating
load_model_callback = LoadModelCallback(
    weights_path=trainer.checkpoint_callback.best_model_path
)
trainer.callbacks.insert(0, load_model_callback)
trainer.test(model=model, datamodule=datamodule)

# %%
RESULT_PATH = os.path.join(
    updated_config['project']['path'],
    updated_config['model']['name'],
    updated_config['dataset']['format'],
    updated_config['dataset']['category']
)
RESULT_PATH

# %%
# a simple function to visualize the model's prediction (anomaly heatmap)
def vis(paths, n_images, is_random=True, figsize=(16, 16)):
    for i in range(n_images):
        image_name = paths[i]
        if is_random: image_name = random.choice(paths)
        img = cv2.imread(image_name)[:,:,::-1]

        category_type = image_name.split('/')[-4:-3:][0]
        defected_type = image_name.split('/')[-2:-1:][0]

        plt.figure(figsize=figsize)
        plt.imshow(img)
        plt.title(
            f"Category : {category_type} and Defected Type : {defected_type}",
            fontdict={'fontsize': 20, 'fontweight': 'medium'}
        )
        plt.xticks([])
        plt.yticks([])
        plt.tight_layout()
    plt.show()

# %%
for content in os.listdir(RESULT_PATH):
    if content == 'images':
        full_path = glob.glob(os.path.join(RESULT_PATH, content, '**',  '*.png'), recursive=True)
        print('Total Image ', len(full_path))
        print(full_path[0].split('/'))
        print(full_path[0].split('/')[-2:-1:])
        print(full_path[0].split('/')[-4:-3:])

# %%
vis(full_path, 10, is_random=True, figsize=(30, 30))

# %% [markdown]
# **Inference**

# %%
from torchvision.datasets.folder import IMG_EXTENSIONS

img_paths = sorted(
        [
            os.path.join(dirpath,filename)
            for dirpath, _, filenames in os.walk(
                os.path.join(config.dataset.path, config.dataset.category, 'test')
            )
            for filename in filenames if filename.endswith(IMG_EXTENSIONS)
            and not filename.startswith(".")
        ],
    )

img_paths = [img_path for img_path in img_paths if not "good" in img_path]
img_paths = random.sample(img_paths, 2)
img_paths

# %%
infer_resutls = "/content/infer_results/"
os.makedirs(infer_resutls, exist_ok=True)
